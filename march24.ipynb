# %%
import pandas as pd
from pandas import DataFrame
from sklearn.datasets import load_iris

# %%
data = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 iris.info()
#
# NameError: name 'iris' is not defined

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
lengthsum = data["sepal.length"].sum()
lengthmean = data["sepal.length"].mean()
lengthmedian = data["sepal.length"].median()
 
print("Sum:",lengthsum, "\nMean:", lengthmean, "\nMedian:",lengthmedian)
# Out:
# Sum: 876.5
# Mean: 5.843333333333334
# Median: 5.8

# %%
lengthmax=data["sepal.length"].max()

# %%
lengthmax
# Out:
# 7.9

# %%
lengthmin=data["sepal.length"].min()

# %%
lengthmin
# Out:
# 4.3

# %%
g = sns.pairplot(data,hue="Species")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 g = sns.pairplot(data,hue="Species")
#
# NameError: name 'sns' is not defined

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 1.9 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
ris = sns.load_dataset("iris")

# %%
g = sns.pairplot(data,hue="variety")

# %%
pip install voila
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 682 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 110 kB 963 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
g = sns.pairplot(data,hue="variety")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['sepal.length'], data['sepal.width'])
plt.title("Scatter Plot")
plt.xlabel('Length')
plt.ylabel('Width')

plt.show()

# %%
plt.plot(data['sepal.length'])
plt.plot(data['sepal.width'])
plt.title("Scatter Plot")
plt.xlabel('Length')
plt.ylabel('Width')

plt.show()

# %%
plt.bar(data['variety'], data['sepal.width'])
plt.title("Scatter Plot")
plt.xlabel('variety')
plt.ylabel('Width')

plt.show()

# %%
widthmean=data['sepal.width'].mean()

# %%
widthmean
# Out:
# 3.0573333333333337

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.plot.area()
# Out:
# <AxesSubplot:>

# %%
data.plot.area(stacked=False)
# Out:
# <AxesSubplot:>
